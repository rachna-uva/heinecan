# %%
#import packages
import os
import re
import string
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import nltk
import fitz
import pandas as pd
from bertopic import BERTopic
import spacy
from spacy.matcher import PhraseMatcher
import random
from collections import defaultdict, Counter
from itertools import combinations
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx
nlp.max_length = 2_000_000  # Adjust this as needed

# %%
# Load spaCy model for NER
nlp = spacy.load('en_core_web_sm')

# Define a dictionary of common abbreviations
abbreviation_map = {
    "WBGT": "Wet Bulb Globe Temperature",
    "AC": "Air Conditioning",
    "UHI": "Urban Heat Island",
    "COP": "Coefficient of Performance",
    "RH": "Relative Humidity",
    "UTCI": "Universal Thermal Climate Index",
    "PPE": "Personal Protective Equipment",
    "OHS": "Occupational Health and Safety",
    "HVAC": "Heating, Ventilation, and Air Conditioning",
    "EMS": "Emergency Medical Services"
}

# keywords focused on core heat stress, cooling methods, physiological terms, and occupational health basics
heat_stress_keywords = [
    # Core concepts
    "heat stress", "thermal stress", "thermal comfort", "heat load", "heat exposure", "heat risk",
    "heat-related illness", "heat exhaustion", "heat stroke", "heat-related mortality",
    "heat index", "WBGT", "UTCI", "Relative Humidity",

    # Cooling strategies
    "cooling zones", "cooling centers", "cooling shelters", "hydration stations", "green roofs",
    "cool roofs", "urban cooling", "natural ventilation", "fans", "air conditioning", 
    "shading structures", "permeable pavements", "green walls", "urban trees", "urban forestry",

    # Worker safety / occupational health
    "rest breaks", "shift scheduling", "hydration", "water supply", "protective clothing", 
    "personal protective equipment", "PPE compliance", "workplace cooling", "safety training", 
    "fatigue prevention", "first aid", "medical response", "heat stress prevention", 
    "occupational safety", "outdoor labor", "industrial heat", "construction safety",

    # Resilience / adaptation
    "acclimatization", "heat acclimatization", "climate resilience", "adaptive capacity",
    "emergency preparedness", "disaster risk reduction", "resilient cities", 
    "early warning systems", "cooling interventions"
]

# focused on broader environmental, urban, climate, health, safety, and single-word keywords to capture diverse contexts
relevant_terms = {
    # Environmental & urban planning
    "urban heat stress", "green infrastructure", "urban adaptation", "urban cooling systems",
    "greenery", "vegetation", "urban forestry", "evapotranspiration", "green roofs", "green walls",
    "cool roofs", "shade provision", "cool pavements", "permeable surfaces", "urban health", 
    "climate-sensitive planning", "climate-smart cities", "nature-based solutions", "albedo",
    "microclimate regulation", "urban heat mitigation", "resilient urban design", 
    "sustainable urban development", "built environment", "thermal insulation",

    # Climate and health
    "extreme heat", "climate change", "environmental heat", "solar radiation", "ambient temperature",
    "humidity", "heat wave", "overheating", "heat-related mortality", "climate vulnerability",
    "weather extremes", "heat adaptation", "public health", "health equity", "environmental justice",

    # Worker protection
    "occupational health", "worker safety", "heat safety training", "industrial safety", 
    "PPE", "shift schedules", "rest breaks", "water access", "dehydration", "outdoor workers",
    "high-risk workers", "fatigue prevention", "first aid", "medical emergency", 
    "construction workers", "farm workers", "workplace safety", "safety measures",

    # Broader interventions
    "cooling technologies", "air conditioning", "fans", "ventilation", "natural cooling", 
    "climate adaptation", "thermal comfort zones", "sustainable cooling", "zero-emission cities",
    "energy efficiency", "energy demand", "climate action plans", "urban ecosystem", "rainwater harvesting",

    # Single keywords (disambiguate based on context in code)
    "temperature", "humidity", "cooling", "shade", "air", "heat", "hydration", "safety", "stress", 
    "resilience", "protection", "exposure", "evaporation", "convection", "conduction", "radiation", 
    "climate", "health", "fatigue", "recovery", "acclimation", "heatstroke", "well-being", 
    "workforce", "monitoring", "risk", "intervention", "emergency", "prevention", "adaptation", 
    "protocol", "response", "vulnerability", "monitor", "workplace"
}

# %%
# Step 1: Load and preprocess
def load_and_clean_text_from_pdf(file_path):
    doc = fitz.open(file_path)
    text = ""
    for page in doc:
        text += page.get_text()
    text = text.lower()
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'\d+', '', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    return text

# %%
# Step 2: Tokenize and Remove Stopwords
def tokenize_and_remove_stopwords(text):
    nltk.download('stopwords', quiet=True)
    from nltk.corpus import stopwords
    stop_words = set(stopwords.words('english'))
    tokens = text.split()
    tokens = [t for t in tokens if t not in stop_words and len(t) > 2]
    return ' '.join(tokens)

# %%
# Step 3: Named Entity Recognition (NER) for heat stress terms
def extract_heat_stress_entities(text):
    doc = nlp(text)
    heat_stress_entities = []
    
    # Customize the entities you're looking for (e.g., cooling shelters, hydration stations)
    for ent in doc.ents:
        if ent.label_ in ['ORG', 'GPE', 'FAC', 'PRODUCT']:  # Organization, Location, Facility, Product
            heat_stress_entities.append(ent.text)
    
    return heat_stress_entities

# %%
# Step 4: Keyword Extraction using TF-IDF (focusing on heat stress)
def extract_heat_stress_keywords(texts, keyword_list):
    vectorizer = TfidfVectorizer(vocabulary=keyword_list, max_df=0.8, min_df=2)
    tfidf_matrix = vectorizer.fit_transform(texts)
    return tfidf_matrix, vectorizer

# %%
# Step 5: Cluster and Extract Top Keywords from Clusters
def cluster_texts(tfidf_matrix, vectorizer, num_clusters=3):
    from sklearn.cluster import KMeans

    km = KMeans(n_clusters=num_clusters, random_state=42)
    km.fit(tfidf_matrix)
    order_centroids = km.cluster_centers_.argsort()[:, ::-1]
    terms = vectorizer.get_feature_names_out()
    
    cluster_keywords = {}
    for i in range(num_clusters):
        top_terms = [terms[ind] for ind in order_centroids[i, :10]]
        cluster_keywords[f"Cluster {i}"] = top_terms
        print(f"\nCluster {i} top keywords:")
        print(", ".join(top_terms))
    
    return km.labels_, cluster_keywords

# %%
# Step 6: Process extracted entities (replace abbreviations, filter terms)
def process_entities(extracted_entities, relevant_terms):
    # Replace abbreviations with full forms
    extracted_entities = [abbreviation_map.get(entity, entity) for entity in extracted_entities]
    
    # Remove duplicates
    extracted_entities = list(set(extracted_entities))
    
    # Filter by relevant terms
    extracted_entities = [entity for entity in extracted_entities if entity.lower() in relevant_terms]
    
    # Remove unwanted symbols or references
    unwanted_symbols = {"•", "ref", "fig", "≥", "≥"}
    extracted_entities = [entity for entity in extracted_entities if entity not in unwanted_symbols]
    print(f'length of extracted_entities after processing: {len(extracted_entities)}')
    return extracted_entities

# %%
# Process pdfs - run above functions
def process_pdfs(random_sample, pdf_folder='papers/'):
    all_pdfs = [f for f in os.listdir(pdf_folder) if f.endswith('.pdf')]

    if random_sample == 1:
        sample_size = min(50, len(all_pdfs))
        sampled_pdfs = random.sample(all_pdfs, sample_size)
    else:
        sampled_pdfs = all_pdfs
        sample_size = len(sampled_pdfs)

    all_entities = []
    for pdf_file in sampled_pdfs:
        file_path = os.path.join(pdf_folder, pdf_file)
        print(f"Processing {pdf_file} ...")
        
        text = load_and_clean_text_from_pdf(file_path)
        cleaned_text = tokenize_and_remove_stopwords(text)
        entities = extract_heat_stress_entities(cleaned_text)
        processed_entities = process_entities(entities, relevant_terms)
        all_entities.extend(processed_entities)

    print(f"Total extracted entities from {sample_size} papers: {len(all_entities)}")
    return all_entities

# TESTRUN: Main pipeline running first on 50 random PDFs, then all papers
# First, only 50 papers will be sampled - to make sure that the code runs as expected
entities_50_papers = process_pdfs(1)
# Out:
# Processing 1-s2.0-S0003687024000589-main.pdf ...
# length of extracted_entities after processing: 1
# Processing Wang-EstimatingOccupationalHeat-2019.pdf ...
# length of extracted_entities after processing: 1
# Processing Xiang-Extremeheatoccupational-2015.pdf ...
# length of extracted_entities after processing: 0
# Processing fpubh-09-713711.pdf ...
# length of extracted_entities after processing: 0
# Processing Morris et al 2020.pdf ...
# length of extracted_entities after processing: 0
# Processing HeatRelatedDeathsAmong-2008.pdf ...
# length of extracted_entities after processing: 0
# Processing Matthews-Communicatingdeadlyconsequences-2017.pdf ...
# length of extracted_entities after processing: 0
# Processing 1-s2.0-S0013935118305772-main.pdf ...
# length of extracted_entities after processing: 0
# Processing Hunt-HeatStrainHydration-2014.pdf ...
# length of extracted_entities after processing: 0
# Processing Effects_of_Heat_Stress_Exposure_and_Clim.pdf ...
# length of extracted_entities after processing: 0
# Processing Enander-Thermalstresshuman-1990.pdf ...
# length of extracted_entities after processing: 0
# Processing Beckett-HeatStressAssociated-1986.pdf ...
# length of extracted_entities after processing: 0
# Processing out.pdf ...
# length of extracted_entities after processing: 0
# Processing strand-HeatStressOccupational-1975.pdf ...
# length of extracted_entities after processing: 0
# Processing ijerph-18-06303-v2.pdf ...
# length of extracted_entities after processing: 0
# Processing GL-PUBLICHEALTHAPPROACH-2015.pdf ...
# length of extracted_entities after processing: 0
# Processing 1-s2.0-S2352710224002535-main.pdf ...
# length of extracted_entities after processing: 1
# Processing Yang-Climaticconditionshuman-2017.pdf ...
# length of extracted_entities after processing: 0
# Processing 83.pdf ...
# length of extracted_entities after processing: 0
# Processing 84.pdf ...
# length of extracted_entities after processing: 0
# Processing Ma-EvaluatingEffectivenessMitigation-2018.pdf ...
# length of extracted_entities after processing: 1
# Processing Oppermann-BeyondThresholdApproaches-2018.pdf ...
# length of extracted_entities after processing: 1
# Processing McAllister-Heat-2022.pdf ...
# length of extracted_entities after processing: 1
# Processing s12889-024-19212-3.pdf ...
# length of extracted_entities after processing: 0
# Processing McKinnon-HeatStressUnderstanding-2005.pdf ...
# length of extracted_entities after processing: 2
# Processing English-EnvironmentalHealthIndicators-2009.pdf ...
# length of extracted_entities after processing: 0
# Processing Calkins-casecrossoverstudyheat-2019.pdf ...
# length of extracted_entities after processing: 0
# Processing Climate change-mediated heat stress vulnerability and adaptation strategies among outdoor workers.pdf ...
# length of extracted_entities after processing: 0
# Processing ALLEN-HeatMitigationSoutheastern-2023.pdf ...
# length of extracted_entities after processing: 0
# Processing HeatLimitWorkers-1974.pdf ...
# length of extracted_entities after processing: 0
# Processing 1-s2.0-S0013935125007467-main.pdf ...
# length of extracted_entities after processing: 0
# Processing American J Industrial Med - 2019 - Binazzi - Evaluation of the impact of heat stress on the occurrence of occupational.pdf ...
# length of extracted_entities after processing: 0
# Processing 1-s2.0-S0306456513000521-main.pdf ...
# length of extracted_entities after processing: 0
# Processing Tustin-RiskFactorsHeatRelated-2018.pdf ...
# length of extracted_entities after processing: 0
# Processing 94.pdf ...
# length of extracted_entities after processing: 1
# Processing 97.pdf ...
# length of extracted_entities after processing: 0
# Processing perceived_heat_stress_and_health_effects_on.8.pdf ...
# length of extracted_entities after processing: 1
# Processing 1-s2.0-S0001457513003230-main.pdf ...
# length of extracted_entities after processing: 1
# Processing Zivin-TemperatureExtremesHealth-2016.pdf ...
# length of extracted_entities after processing: 0
# Processing 1-s2.0-S0169204614000498-main.pdf ...
# length of extracted_entities after processing: 0
# Processing Organization-Heatrelatedhealthinformation-2021.pdf ...
# length of extracted_entities after processing: 0
# Processing Brake-FluidLossesHydration-2003.pdf ...
# length of extracted_entities after processing: 0
# Processing Dash-Workplaceheatstress-2011.pdf ...
# length of extracted_entities after processing: 0
# Processing 1-s2.0-S0048969718323313-main.pdf ...
# length of extracted_entities after processing: 0
# Processing ijerph-21-01255.pdf ...
# length of extracted_entities after processing: 0
# Processing s12940-020-00641-7.pdf ...
# length of extracted_entities after processing: 1
# Processing s40279-022-01677-0.pdf ...
# length of extracted_entities after processing: 1
# Processing 0.pdf ...
# length of extracted_entities after processing: 0
# Processing 1-s2.0-S0360132325002653-main.pdf ...
# length of extracted_entities after processing: 0
# Processing s12992-020-00554-7.pdf ...
# length of extracted_entities after processing: 0
# Total extracted entities from 50 papers: 13

# %%
# Now, all papers will be processed
entities_all_papers = process_pdfs(0)
# Out:
# Processing 0.pdf ...
# length of extracted_entities after processing: 0
# Processing 1-s2.0-S0001457513003230-main.pdf ...
# length of extracted_entities after processing: 1
# Processing 1-s2.0-S0003687024000589-main.pdf ...
# length of extracted_entities after processing: 1
# Processing 1-s2.0-S0013935118305772-main.pdf ...
# length of extracted_entities after processing: 0
# Processing 1-s2.0-S001393512100075X-main.pdf ...
# length of extracted_entities after processing: 2
# Processing 1-s2.0-S0013935125007467-main.pdf ...
# length of extracted_entities after processing: 0
# Processing 1-s2.0-S0048969718323313-main.pdf ...
# length of extracted_entities after processing: 0
# Processing 1-s2.0-S0048969721033313-main.pdf ...
# length of extracted_entities after processing: 0
# Processing 1-s2.0-S0169204614000498-main.pdf ...
# length of extracted_entities after processing: 0
# Processing 1-s2.0-S0306456513000521-main.pdf ...
# length of extracted_entities after processing: 0
# Processing 1-s2.0-S0360132325002653-main.pdf ...
# length of extracted_entities after processing: 0
# Processing 1-s2.0-S0378778818326227-main.pdf ...
# length of extracted_entities after processing: 0
# Processing 1-s2.0-S0925753517313437-main.pdf ...
# length of extracted_entities after processing: 1
# Processing 1-s2.0-S1440244021000530-main.pdf ...
# length of extracted_entities after processing: 0
# Processing 1-s2.0-S2093791116302220-main.pdf ...
# length of extracted_entities after processing: 0
# Processing 1-s2.0-S2352710224002535-main.pdf ...
# length of extracted_entities after processing: 1
# Processing 10.1515_reveh-2020-0158.pdf ...
# length of extracted_entities after processing: 0
# Processing 1471-2458-13-1004.pdf ...
# length of extracted_entities after processing: 0
# Processing 18.pdf ...
# length of extracted_entities after processing: 2
# Processing 2021-06.pdf ...
# length of extracted_entities after processing: 1
# Processing 44_331.pdf ...
# length of extracted_entities after processing: 0
# Processing 6.pdf ...
# length of extracted_entities after processing: 1
# Processing 64.pdf ...
# length of extracted_entities after processing: 0
# Processing 67.pdf ...
# length of extracted_entities after processing: 0
# Processing 7.pdf ...
# length of extracted_entities after processing: 0
# Processing 83.pdf ...
# length of extracted_entities after processing: 0
# Processing 84.pdf ...
# length of extracted_entities after processing: 0
# Processing 94.pdf ...
# length of extracted_entities after processing: 1
# Processing 97.pdf ...
# length of extracted_entities after processing: 0
# Processing AbstractsISEE22nd-2011.pdf ...
# length of extracted_entities after processing: 1
# Processing AdamPoupart-Effectsummeroutdoor-2015.pdf ...
# length of extracted_entities after processing: 0
# Processing ALLEN-HeatMitigationSoutheastern-2023.pdf ...
# length of extracted_entities after processing: 0
# Processing American J Industrial Med - 2019 - Binazzi - Evaluation of the impact of heat stress on the occurrence of occupational.pdf ...
# length of extracted_entities after processing: 0
# Processing American J Industrial Med - 2024 - Tetzlaff - Practical Considerations for Using Personal Cooling Garments for Heat Stress.pdf ...
# length of extracted_entities after processing: 0
# Processing annurev-publhealth-060222-034715.pdf ...
# length of extracted_entities after processing: 1
# Processing applsci-13-08561.pdf ...
# length of extracted_entities after processing: 0
# Processing Arbury-HeatIllnessDeath-2014.pdf ...
# length of extracted_entities after processing: 0
# Processing Arundel-IndirectHealthEffects-1986.pdf ...
# length of extracted_entities after processing: 0
# Processing Axelson-Influenceheatexposure-1974.pdf ...
# length of extracted_entities after processing: 0
# Processing Baccini-HeatEffectsMortality-2008.pdf ...
# length of extracted_entities after processing: 0
# Processing Beckett-HeatStressAssociated-1986.pdf ...
# length of extracted_entities after processing: 0
# Processing Benmarhnia-VulnerabilityHeatrelatedMortality-2015.pdf ...
# length of extracted_entities after processing: 0
# Processing Bodin-Interventionreduceheat-2016.pdf ...
# length of extracted_entities after processing: 0
# Processing Brake-DeepBodyCore-2002.pdf ...
# length of extracted_entities after processing: 0
# Processing Brake-FluidLossesHydration-2003.pdf ...
# length of extracted_entities after processing: 0
# Processing Brearley-InfluenceChronicHeat-2016.pdf ...
# length of extracted_entities after processing: 0
# Processing Broberg-Waterrestshade-2018.pdf ...
# length of extracted_entities after processing: 0
# Processing Bush-ImpactsClimateChange-2011.pdf ...
# length of extracted_entities after processing: 0
# Processing Calkins-casecrossoverstudyheat-2019.pdf ...
# length of extracted_entities after processing: 0
# Processing Case studies on heat stress related perceptions in different industrial sectors in southern India.pdf ...
# length of extracted_entities after processing: 1
# Processing Choudhary-HeatStressIllness-2014.pdf ...
# length of extracted_entities after processing: 0
# Processing Ciuha-InteractionIndoorOccupational-2019.pdf ...
# length of extracted_entities after processing: 0
# Processing Climate change-mediated heat stress vulnerability and adaptation strategies among outdoor workers.pdf ...
# length of extracted_entities after processing: 0
# Processing Dahl-HeatIndex-2019.pdf ...
# length of extracted_entities after processing: 0
# Processing Dash-Workplaceheatstress-2011.pdf ...
# length of extracted_entities after processing: 0
# Processing document.pdf ...
# length of extracted_entities after processing: 1
# Processing DukesDobos-Hazardsheatexposure-1981.pdf ...
# length of extracted_entities after processing: 0
# Processing Effects_of_Heat_Stress_Exposure_and_Clim.pdf ...
# length of extracted_entities after processing: 0
# Processing Emmanuel-Urbanheatislands-2007.pdf ...
# length of extracted_entities after processing: 2
# Processing Enander-Thermalstresshuman-1990.pdf ...
# length of extracted_entities after processing: 0
# Processing English-EnvironmentalHealthIndicators-2009.pdf ...
# length of extracted_entities after processing: 0
# Processing Evaluation of heat stress and heat strain among employees working outdoors in an extremely hot environment.pdf ...
# length of extracted_entities after processing: 0
# Processing Fortune-WorkattributedIllnessArising-2013.pdf ...
# length of extracted_entities after processing: 0
# Processing fpubh-09-713711.pdf ...
# length of extracted_entities after processing: 0
# Processing fpubh-10-782811.pdf ...
# length of extracted_entities after processing: 0
# Processing fpubh-12-1477186.pdf ...
# length of extracted_entities after processing: 0
# Processing fspor-05-1274141.pdf ...
# length of extracted_entities after processing: 0
# Processing GeoHealth - 2021 - Morrissey - Heat Safety in the Workplace  Modified Delphi Consensus to Establish Strategies and.pdf ...
# length of extracted_entities after processing: 1
# Processing GL-PUBLICHEALTHAPPROACH-2015.pdf ...
# length of extracted_entities after processing: 0
# Processing Hanna and Brown 1983.pdf ...
# length of extracted_entities after processing: 0
# Processing Hanna-ClimateChangeRising-2011.pdf ...
# length of extracted_entities after processing: 0
# Processing Health vs. wealth  Employer  employee and policy-maker perspectives on occupational heat stress across multiple European industries (1).pdf ...
# length of extracted_entities after processing: 0
# Processing Health vs. wealth  Employer  employee and policy-maker perspectives on occupational heat stress across multiple European industries.pdf ...
# length of extracted_entities after processing: 0
# Processing Heat stress and inadequate sanitary facilities at workplaces   an occupational health concern for women .pdf ...
# length of extracted_entities after processing: 0
# Processing HeatLimitWorkers-1974.pdf ...
# length of extracted_entities after processing: 0
# Processing HeatRelatedDeathsAmong-2008.pdf ...
# length of extracted_entities after processing: 0
# Processing Hunt-HeatStrainHydration-2014.pdf ...
# length of extracted_entities after processing: 0
# Processing ijerph-15-00247.pdf ...
# length of extracted_entities after processing: 0
# Processing ijerph-16-00597.pdf ...
# length of extracted_entities after processing: 0
# Processing ijerph-17-06363-v2.pdf ...
# length of extracted_entities after processing: 0
# Processing ijerph-18-06303-v2.pdf ...
# length of extracted_entities after processing: 0
# Processing ijerph-19-07950-v2.pdf ...
# length of extracted_entities after processing: 1
# Processing ijerph-21-01255.pdf ...
# length of extracted_entities after processing: 0
# Processing ijerph-21-01681.pdf ...
# length of extracted_entities after processing: 1
# Processing journal.pclm.0000202.pdf ...
# length of extracted_entities after processing: 1
# Processing Kjellstrom-ImpactClimateConditions-2016.pdf ...
# length of extracted_entities after processing: 0
# Processing Li-RapidWarmingSummer-2020.pdf ...
# length of extracted_entities after processing: 1
# Processing Lundgren.pdf ...
# length of extracted_entities after processing: 0
# Processing Ma-EvaluatingEffectivenessMitigation-2018.pdf ...
# length of extracted_entities after processing: 1
# Processing Matthews-Communicatingdeadlyconsequences-2017.pdf ...
# length of extracted_entities after processing: 0
# Processing McAllister-Heat-2022.pdf ...
# length of extracted_entities after processing: 1
# Processing McDonald-HeatStressImproving-2008.pdf ...
# length of extracted_entities after processing: 0
# Processing McKinnon-HeatStressUnderstanding-2005.pdf ...
# length of extracted_entities after processing: 2
# Processing MDL-109-163.pdf ...
# length of extracted_entities after processing: 0
# Processing MITCHELL-URBANHEATCLIMATE-2014.pdf ...
# length of extracted_entities after processing: 0
# Processing moran-et-al-2023-beating-the-heat-military-training-and-operations-in-the-era-of-global-warming.pdf ...
# length of extracted_entities after processing: 1
# Processing Morris et al 2020.pdf ...
# length of extracted_entities after processing: 0
# Processing MUNSLOW-GlobalisationClimateChange-2010.pdf ...
# length of extracted_entities after processing: 0
# Processing Occupational heat strain in outdoor workers  A comprehensive review and meta-analysis.pdf ...
# length of extracted_entities after processing: 1
# Processing Ohashi-NumericalSimulationsOutdoor-2014.pdf ...
# length of extracted_entities after processing: 1
# Processing ONeill-TemperatureExtremesHealth-2009.pdf ...
# length of extracted_entities after processing: 0
# Processing Oppermann-BeyondThresholdApproaches-2018.pdf ...
# length of extracted_entities after processing: 1
# Processing Organization-Heatrelatedhealthinformation-2021.pdf ...
# length of extracted_entities after processing: 0
# Processing Organization-Longtermurbanplanning-2021.pdf ...
# length of extracted_entities after processing: 1
# Processing Organization-Reductionsindoorheat-2021.pdf ...
# length of extracted_entities after processing: 0
# Processing out.pdf ...
# length of extracted_entities after processing: 0
# Processing perceived_heat_stress_and_health_effects_on.8.pdf ...
# length of extracted_entities after processing: 1
# Processing Picchio-HighTemperaturesWorkplace-2024.pdf ...
# length of extracted_entities after processing: 0
# Processing preprints202410.1280.v1.pdf ...
# length of extracted_entities after processing: 0
# Processing Ramsey-Practicalevaluationhot-1987.pdf ...
# length of extracted_entities after processing: 1
# Processing Rasdan_Ismail_2020_J._Phys.%3A_Conf._Ser._1630_012001.pdf ...
# length of extracted_entities after processing: 0
# Processing Reid-EvaluationHeatVulnerability-2012.pdf ...
# length of extracted_entities after processing: 0
# Processing Ricketts-CaseOVERHEATEDCONSTRUCTION-2020.pdf ...
# length of extracted_entities after processing: 1
# Processing s00420-021-01711-0.pdf ...
# length of extracted_entities after processing: 0
# Processing s00484-017-1352-y.pdf ...
# length of extracted_entities after processing: 1
# Processing s12889-024-19212-3.pdf ...
# length of extracted_entities after processing: 0
# Processing s12940-020-00641-7.pdf ...
# length of extracted_entities after processing: 1
# Processing s12992-020-00554-7.pdf ...
# length of extracted_entities after processing: 0
# Processing s13143-023-00326-4.pdf ...
# length of extracted_entities after processing: 0
# Processing s40201-015-0199-6.pdf ...
# length of extracted_entities after processing: 1
# Processing s40279-022-01677-0.pdf ...
# length of extracted_entities after processing: 1
# Processing s40572-025-00481-y.pdf ...
# length of extracted_entities after processing: 0
# Processing Seeba-FeelingHeat-2017.pdf ...
# length of extracted_entities after processing: 0
# Processing strand-HeatStressOccupational-1975.pdf ...
# length of extracted_entities after processing: 0
# Processing sustainability-14-09234-v2.pdf ...
# length of extracted_entities after processing: 0
# Processing Tuholske-Globalurbanpopulation-2021.pdf ...
# length of extracted_entities after processing: 0
# Processing Tustin-EvaluationOccupationalExposure-2018.pdf ...
# length of extracted_entities after processing: 0
# Processing Tustin-RiskFactorsHeatRelated-2018.pdf ...
# length of extracted_entities after processing: 0
# Processing Understanding and perceiving heat stress risk control  Critical insights from agriculture workers.pdf ...
# length of extracted_entities after processing: 0
# Processing Vaidyanathan-Assessmentextremeheat-2019.pdf ...
# length of extracted_entities after processing: 0
# Processing Vaneckova-BiometeorologicalIndicesImprove-2011.pdf ...
# length of extracted_entities after processing: 0
# Processing Wang-EstimatingOccupationalHeat-2019.pdf ...
# length of extracted_entities after processing: 1
# Processing WOJTCZAKJAROSZOWA-HealthComplaintsSicknesses-1986.pdf ...
# length of extracted_entities after processing: 0
# Processing wxaa082 - UTCI.pdf ...
# length of extracted_entities after processing: 1
# Processing Xiang-Extremeheatoccupational-2015.pdf ...
# length of extracted_entities after processing: 0
# Processing Yang-Climaticconditionshuman-2017.pdf ...
# length of extracted_entities after processing: 0
# Processing Yang-ImpactTemperaturePhysical-2021.pdf ...
# length of extracted_entities after processing: 0
# Processing Zivin-TemperatureExtremesHealth-2016.pdf ...
# length of extracted_entities after processing: 0
# Total extracted entities from 138 papers: 40

# %% [markdown]
# <h3> In summary, we have 40 extracted entities from 138 research papers related to heat stress - this is only 0.28 entities per paper, which could indicate that the filtering is too restricted, or that spaCy's general NER model may not be well-suited for exploring heat stress. Now, we will try some different approaches. </h3>

# %%
# Prepare matcher
matcher = PhraseMatcher(nlp.vocab, attr="LOWER")

# Convert keyword list to patterns
phrases = heat_stress_keywords
patterns = [nlp.make_doc(text) for text in phrases]
matcher.add("HEAT_STRESS_TERM", patterns)

def extract_matched_phrases(text):
    doc = nlp(text)
    matches = matcher(doc)
    return list(set([doc[start:end].text for match_id, start, end in matches]))

# %%
# Improved entity recognition

# Approach 1: Use PhraseMatcher instead of NER for domain-specific terms
def extract_domain_entities_v2(text):
    """Extract entities using PhraseMatcher for better domain coverage"""
    doc = nlp(text)
    matches = matcher(doc)
    matched_entities = []
    
    for match_id, start, end in matches:
        span = doc[start:end]
        matched_entities.append(span.text)
    
    return list(set(matched_entities))

# Approach 2: Combine multiple extraction methods
def extract_comprehensive_entities(text):
    """Combine NER, PhraseMatcher, and regex patterns"""
    doc = nlp(text)
    all_entities = []
    
    # Method 1: Traditional NER
    for ent in doc.ents:
        if ent.label_ in ['ORG', 'GPE', 'FAC', 'PRODUCT', 'PERSON']:
            all_entities.append(ent.text)
    
    # Method 2: PhraseMatcher for domain terms
    matches = matcher(doc)
    for match_id, start, end in matches:
        span = doc[start:end]
        all_entities.append(span.text)
    
    # Method 3: Regex for specific patterns (measurements, standards)
    # Find temperature measurements
    temp_pattern = r'\b\d+[°℃℉]\s*[CF]?\b'
    temps = re.findall(temp_pattern, text)
    all_entities.extend(temps)
    
    # Find WBGT measurements
    wbgt_pattern = r'WBGT\s*[><=]?\s*\d+[°℃℉]?'
    wbgts = re.findall(wbgt_pattern, text, re.IGNORECASE)
    all_entities.extend(wbgts)
    
    return list(set(all_entities))

# Approach 3: Expand relevant terms with more variations
# Combine with existing relevant_terms
expanded_relevant_terms = set(relevant_terms) | {
    # Measurement and assessment terms
    "wet bulb globe temperature", "wbgt", "heat index", "humidex", 
    "thermal work limit", "physiological strain index", "core temperature",
    "sweat rate", "metabolic rate", "thermal sensation", "thermal comfort",
    
    # Specific interventions
    "cooling vest", "ice vest", "cooling towel", "misting system",
    "evaporative cooling", "radiant cooling", "mechanical ventilation",
    "work-rest cycles", "heat acclimatization program", "hydration protocol",
    
    # Occupational categories
    "construction worker", "agricultural worker", "firefighter", 
    "steel worker", "foundry worker", "outdoor laborer", "roofer",
    
    # Organizations and standards
    "osha", "niosh", "acgih", "iso", "astm", "ashrae",
    "occupational safety and health administration",
    "american conference of governmental industrial hygienists",
    
    # Medical terms
    "heat exhaustion", "heat stroke", "heat cramps", "heat rash",
    "dehydration", "hyperthermia", "thermoregulation", "heat illness",
    
    # Geographic and temporal
    "summer months", "hot climate", "tropical region", "desert climate",
    "heat wave", "extreme temperature", "global warming"
}

# Approach 4: Use noun phrase extraction
def extract_noun_phrases(text):
    """Extract noun phrases that might contain relevant concepts"""
    doc = nlp(text)
    noun_phrases = []
    
    for chunk in doc.noun_chunks:
        # Filter for phrases containing heat-related terms
        chunk_lower = chunk.text.lower()
        if any(term in chunk_lower for term in ['heat', 'thermal', 'cool', 'temperature', 'stress', 'work']):
            if len(chunk.text.split()) <= 4:  # Keep shorter phrases
                noun_phrases.append(chunk.text)
    
    return list(set(noun_phrases))

# Approach 5: Frequency-based filtering
def extract_frequent_terms(texts, min_freq=3):
    """Extract terms that appear frequently across documents"""
    all_terms = []
    for text in texts:
        try:
            doc = nlp(text)
            # Extract noun phrases and named entities
            for chunk in doc.noun_chunks:
                if 2 <= len(chunk.text.split()) <= 3:  # 2-3 word phrases
                    all_terms.append(chunk.text.lower())
            
            for ent in doc.ents:
                all_terms.append(ent.text.lower())
        except Exception as e:
            print(f"Error processing text: {e}")
            continue
    
    # Count frequencies and filter
    term_counts = Counter(all_terms)
    frequent_terms = [term for term, count in term_counts.items() if count >= min_freq]
    
    return frequent_terms, term_counts

# Modified main processing function
def process_entities_improved(extracted_entities, relevant_terms, min_length=3):
    """Improved entity processing with better filtering"""
    
    # Replace abbreviations
    processed = [abbreviation_map.get(entity, entity) for entity in extracted_entities]
    
    # Remove very short terms (unless they're known abbreviations)
    known_abbrevs = set(abbreviation_map.keys())
    processed = [entity for entity in processed 
                if len(entity) >= min_length or entity.upper() in known_abbrevs]
    
    # Remove duplicates (case-insensitive)
    seen = set()
    unique_entities = []
    for entity in processed:
        entity_lower = entity.lower()
        if entity_lower not in seen:
            seen.add(entity_lower)
            unique_entities.append(entity)
    
    # Filter by relevance (more flexible matching)
    relevant_entities = []
    for entity in unique_entities:
        entity_lower = entity.lower()
        # Exact match or partial match for longer terms
        if (entity_lower in relevant_terms or 
            any(term in entity_lower for term in relevant_terms if len(term) > 5)):
            relevant_entities.append(entity)
    
    return relevant_entities

# Function to examine current entities
def examine_entities(entities_list):
    """Examine the extracted entities"""
    print(f"Total unique entities: {len(set(entities_list))}")
    print(f"Total entities (with duplicates): {len(entities_list)}")
    
    # Count frequencies
    entity_counts = Counter(entities_list)
    
    print("\nMost frequent entities:")
    for entity, count in entity_counts.most_common(20):
        print(f"  {entity}: {count}")
    
    print(f"\nAll unique entities:")
    for entity in sorted(set(entities_list)):
        print(f"  - {entity}")
    
    return entity_counts

# Quick test of improved extraction on a sample
def test_improved_extraction(sample_size=5):
    """Test the improved extraction on a few files"""
    pdf_folder = 'papers/'
    all_pdfs = [f for f in os.listdir(pdf_folder) if f.endswith('.pdf')]
    sample_pdfs = all_pdfs[:sample_size]
    
    print("Testing improved extraction...")
    all_entities = []
    
    for pdf_file in sample_pdfs:
        file_path = os.path.join(pdf_folder, pdf_file)
        print(f"\nProcessing {pdf_file}...")
        
        try:
            text = load_and_clean_text_from_pdf(file_path)
            
            # Method 1: Your original NER approach
            original_entities = extract_heat_stress_entities(text)
            original_processed = process_entities(original_entities, relevant_terms)
            
            # Method 2: PhraseMatcher approach
            phrase_entities = extract_domain_entities_v2(text)
            phrase_processed = process_entities_improved(phrase_entities, expanded_relevant_terms)
            
            # Method 3: Noun phrases
            noun_entities = extract_noun_phrases(text)
            noun_processed = process_entities_improved(noun_entities, expanded_relevant_terms)
            
            # Combine all methods
            combined = list(set(original_processed + phrase_processed + noun_processed))
            all_entities.extend(combined)
            
            print(f"  Original method: {len(original_processed)} entities")
            print(f"  PhraseMatcher: {len(phrase_processed)} entities") 
            print(f"  Noun phrases: {len(noun_processed)} entities")
            print(f"  Combined unique: {len(combined)} entities")
            
            if combined:
                print(f"  Sample entities: {combined[:5]}")
                
        except Exception as e:
            print(f"  Error processing {pdf_file}: {e}")
    
    print(f"\nTotal entities from {sample_size} files: {len(all_entities)}")
    return all_entities

# Run the test
print("=== EXAMINING THE CURRENT ENTITIES ===")
current_entity_counts = examine_entities(entities_all_papers)

print("\n" + "="*50)
print("=== TESTING IMPROVED EXTRACTION ===")
improved_entities = test_improved_extraction(5)
# Out:
# === EXAMINING THE CURRENT ENTITIES ===
# Total unique entities: 5
# Total entities (with duplicates): 40
#
# Most frequent entities:
#   wbgt: 19
#   ppe: 12
#   albedo: 4
#   greenery: 3
#   healthcare: 2
#
# All unique entities:
#   - albedo
#   - greenery
#   - healthcare
#   - ppe
#   - wbgt
#
# ==================================================
# === TESTING IMPROVED EXTRACTION ===
# Testing improved extraction...
#
# Processing 0.pdf...
# length of extracted_entities after processing: 0
#   Original method: 0 entities
#   PhraseMatcher: 21 entities
#   Noun phrases: 130 entities
#   Combined unique: 146 entities
#   Sample entities: ['physiological heat loss responses', 'core temperature', 'the temperature', 'body temperature', 'heat exposure']
#
# Processing 1-s2.0-S0001457513003230-main.pdf...
# length of extracted_entities after processing: 1
#   Original method: 1 entities
#   PhraseMatcher: 19 entities
#   Noun phrases: 110 entities
#   Combined unique: 122 entities
#   Sample entities: ['workplace characteristics', 'an effective temperature scale', 'the environmental temperature', 'heat stressrelated accidents', 'the temperature']
#
# Processing 1-s2.0-S0003687024000589-main.pdf...
# length of extracted_entities after processing: 1
#   Original method: 1 entities
#   PhraseMatcher: 14 entities
#   Noun phrases: 82 entities
#   Combined unique: 94 entities
#   Sample entities: ['the maximum monthly temperatures', 'the temperature', 'heatstress mitigation strategies', 'tm  cooling vests', 'the workplace brooks']
#
# Processing 1-s2.0-S0013935118305772-main.pdf...
# length of extracted_entities after processing: 0
#   Original method: 0 entities
#   PhraseMatcher: 13 entities
#   Noun phrases: 59 entities
#   Combined unique: 68 entities
#   Sample entities: ['the wet bulb temperature', 'farm workers', 'heat exposure risks', 'heat radiation', 'heat exposuren']
#
# Processing 1-s2.0-S001393512100075X-main.pdf...
# length of extracted_entities after processing: 1
#   Original method: 1 entities
#   PhraseMatcher: 13 entities
#   Noun phrases: 86 entities
#   Combined unique: 96 entities
#   Sample entities: ['workplace characteristics', 'workplace heat management policies', 'industrial heat stress', 'the temperature', 'heat exposure']
#
# Total entities from 5 files: 526

# %%
# Perform improved extraction on all papers
def extract_entities_all_papers_improved():
    """Apply improved entity extraction to all PDF papers"""
    pdf_folder = 'papers/'
    all_pdfs = [f for f in os.listdir(pdf_folder) if f.endswith('.pdf')]
    
    print(f"Found {len(all_pdfs)} PDF files to process")
    print("Starting improved entity extraction on all papers...")
    
    all_entities_improved = []
    file_entity_counts = {}
    processing_stats = {
        'successful': 0,
        'failed': 0,
        'total_entities': 0
    }
    
    for i, pdf_file in enumerate(all_pdfs, 1):
        file_path = os.path.join(pdf_folder, pdf_file)
        print(f"\n[{i}/{len(all_pdfs)}] Processing {pdf_file}...")
        
        try:
            # Load and clean text
            text = load_and_clean_text_from_pdf(file_path)
            
            if not text or len(text.strip()) < 100:
                print(f"  Warning: Very short or empty text extracted")
                continue
            
            # Apply all improved extraction methods
            file_entities = []
            
            # Method 1: Comprehensive extraction (NER + PhraseMatcher + Regex)
            comprehensive_entities = extract_comprehensive_entities(text)
            comprehensive_processed = process_entities_improved(comprehensive_entities, expanded_relevant_terms)
            file_entities.extend(comprehensive_processed)
            
            # Method 2: Domain-specific PhraseMatcher
            phrase_entities = extract_domain_entities_v2(text)
            phrase_processed = process_entities_improved(phrase_entities, expanded_relevant_terms)
            file_entities.extend(phrase_processed)
            
            # Method 3: Noun phrase extraction
            noun_entities = extract_noun_phrases(text)
            noun_processed = process_entities_improved(noun_entities, expanded_relevant_terms)
            file_entities.extend(noun_processed)
            
            # Remove duplicates from this file
            file_entities_unique = list(set(file_entities))
            
            # Add to overall collection
            all_entities_improved.extend(file_entities_unique)
            file_entity_counts[pdf_file] = len(file_entities_unique)
            
            processing_stats['successful'] += 1
            processing_stats['total_entities'] += len(file_entities_unique)
            
            print(f"  ✓ Extracted {len(file_entities_unique)} unique entities")
            if file_entities_unique:
                print(f"  Sample: {file_entities_unique[:3]}")
                
        except Exception as e:
            print(f"  ✗ Error processing {pdf_file}: {e}")
            processing_stats['failed'] += 1
            continue
    
    # Final statistics
    print(f"\n{'='*60}")
    print("PROCESSING COMPLETE")
    print(f"{'='*60}")
    print(f"Successfully processed: {processing_stats['successful']} files")
    print(f"Failed to process: {processing_stats['failed']} files")
    print(f"Total entities extracted: {processing_stats['total_entities']}")
    print(f"Unique entities across all papers: {len(set(all_entities_improved))}")
    
    return all_entities_improved, file_entity_counts, processing_stats

# Run the improved extraction on all papers
print("Starting improved entity extraction on all papers...")
entities_all_papers_improved, file_counts_improved, stats_improved = extract_entities_all_papers_improved()

# Analyze the results
print(f"\n{'='*60}")
print("ANALYSIS OF IMPROVED EXTRACTION RESULTS")
print(f"{'='*60}")
"""
# Compare with original results if available
if 'entities_all_papers' in globals():
    original_unique = len(set(entities_all_papers))
    improved_unique = len(set(entities_all_papers_improved))
    print(f"Original extraction: {original_unique} unique entities")
    print(f"Improved extraction: {improved_unique} unique entities")
    print(f"Improvement: +{improved_unique - original_unique} entities ({((improved_unique/original_unique)-1)*100:.1f}% increase)")
"""
# Entity frequency analysis
entity_counts_improved = Counter(entities_all_papers_improved)

print(f"\nTop 20 most frequent entities (improved method):")
for entity, count in entity_counts_improved.most_common(20):
    print(f"  {entity}: {count}")

# Files with most entities
print(f"\nTop 10 files by entity count:")
sorted_files = sorted(file_counts_improved.items(), key=lambda x: x[1], reverse=True)
for filename, count in sorted_files[:10]:
    print(f"  {filename}: {count} entities")
# Out:
# Starting improved entity extraction on all papers...
# Found 138 PDF files to process
# Starting improved entity extraction on all papers...
#
# [1/138] Processing 0.pdf...
#   ✓ Extracted 161 unique entities
#   Sample: ['sydney school of health sciences prof', 'physiological heat loss responses', 'core temperature']
#
# [2/138] Processing 1-s2.0-S0001457513003230-main.pdf...
#   ✓ Extracted 131 unique entities
#   Sample: ['workplace characteristics', 'an effective temperature scale', 'the environmental temperature']
#
# [3/138] Processing 1-s2.0-S0003687024000589-main.pdf...
#   ✓ Extracted 101 unique entities
#   Sample: ['the maximum monthly temperatures', 'the temperature', 'heatstress mitigation strategies']
#
# [4/138] Processing 1-s2.0-S0013935118305772-main.pdf...
#   ✓ Extracted 70 unique entities
#   Sample: ['the wet bulb temperature', 'farm workers', 'heat exposure risks']
#
# [5/138] Processing 1-s2.0-S001393512100075X-main.pdf...
#   ✓ Extracted 101 unique entities
#   Sample: ['workplace characteristics', 'workplace heat management policies', 'industrial heat stress']
#
# [6/138] Processing 1-s2.0-S0013935125007467-main.pdf...
#   ✓ Extracted 137 unique entities
#   Sample: ['workplace safety guidelines', 'direct heat exposure', 'c dry bulb temperature']
#
# [7/138] Processing 1-s2.0-S0048969718323313-main.pdf...
#   ✓ Extracted 133 unique entities
#   Sample: ['the varying heat stress', 'workplace conditions', 'tional heat stress']
#
# [8/138] Processing 1-s2.0-S0048969721033313-main.pdf...
#   ✓ Extracted 116 unique entities
#   Sample: ['farm workers', 'heathealth impacts table', 'core temperature']
#
# [9/138] Processing 1-s2.0-S0169204614000498-main.pdf...
#   ✓ Extracted 62 unique entities
#   Sample: ['air temperature', 'an effective temperature scale', 'strong afternoon heat stresses']
#
# [10/138] Processing 1-s2.0-S0306456513000521-main.pdf...
#   ✓ Extracted 88 unique entities
#   Sample: ['arm immersion cooling system', 'water temperature', 'core temperature']
#
# [11/138] Processing 1-s2.0-S0360132325002653-main.pdf...
#   ✓ Extracted 84 unique entities
#   Sample: ['core temperature', 'heat exposure', 'both ambient temperature']
#
# [12/138] Processing 1-s2.0-S0378778818326227-main.pdf...
#   ✓ Extracted 57 unique entities
#   Sample: ['selected workplaces', 'air temperature', 'hyperthermic humans temperature']
#
# [13/138] Processing 1-s2.0-S0925753517313437-main.pdf...
#   ✓ Extracted 126 unique entities
#   Sample: ['heat exposure tawatsupa', 'higher temperatures spector', 'body temperature']
#
# [14/138] Processing 1-s2.0-S1440244021000530-main.pdf...
#   ✓ Extracted 93 unique entities
#   Sample: ['moderate heat stress', 'existing heathealth warning systems', 'the thermal insulation']
#
# [15/138] Processing 1-s2.0-S2093791116302220-main.pdf...
#   ✓ Extracted 84 unique entities
#   Sample: ['heat exposure health impacts', 'heat exposure', 'ambient temperatures']
#
# [16/138] Processing 1-s2.0-S2352710224002535-main.pdf...
#   ✓ Extracted 175 unique entities
#   Sample: ['semiconductor cooling device scd', 'core temperature', 'personal thermal comfort management']
#
# [17/138] Processing 10.1515_reveh-2020-0158.pdf...
#   ✓ Extracted 125 unique entities
#   Sample: ['roomtemperature workers p  changes', 'florida agricultural workers', 'al occupational exposures']
#
# [18/138] Processing 1471-2458-13-1004.pdf...
#   ✓ Extracted 62 unique entities
#   Sample: ['agricultural workplaces', 'personal protective equipmentworkplace prevention', 'farm workers']
#
# [19/138] Processing 18.pdf...
#   ✓ Extracted 148 unique entities
#   Sample: ['evaporative cooling greenery', 'higher cooling efficiency', 'heat waves energy build']
#
# [20/138] Processing 2021-06.pdf...
#   ✓ Extracted 275 unique entities
#   Sample: ['workers’ protection', 'national heat health action', 'core temperature']
#
# [21/138] Processing 44_331.pdf...
#   ✓ Extracted 125 unique entities
#   Sample: ['reduced tissue temperatures', 'thermallystressful environments', 'air and skin temperatures']
#
# [22/138] Processing 6.pdf...
#   ✓ Extracted 160 unique entities
#   Sample: ['farm workers', 'exertional heat stroke monitoring', 'unprotected healthy workers']
#
# [23/138] Processing 64.pdf...
#   ✓ Extracted 59 unique entities
#   Sample: ['air temperature', 'proportional eg higher temperature', 'overall higher temperatures']
#
# [24/138] Processing 67.pdf...
#   ✓ Extracted 15 unique entities
#   Sample: ['the color temperature', 'treadmill stress testing', 'stress imaging']
#
# [25/138] Processing 7.pdf...
#   ✓ Extracted 80 unique entities
#   Sample: ['workplace conditions', 'farm workers', 'core temperature']
#
# [26/138] Processing 83.pdf...
#   ✓ Extracted 8 unique entities
#   Sample: ['stress', 'vagal stimulation body temperature', 'the caesar cardioprotection consortium abstract']
#
# [27/138] Processing 84.pdf...
#   ✓ Extracted 23 unique entities
#   Sample: ['the human thermal comfort', 'apparent temperature', 'heat exposure']
#
# [28/138] Processing 94.pdf...
#   ✓ Extracted 13 unique entities
#   Sample: ['reduced stress', 'air conditioning', 'stressful life events']
#
# [29/138] Processing 97.pdf...
#   ✓ Extracted 60 unique entities
#   Sample: ['a core temperature', 'the same cooling techniques', 'the national association of emergency medical']
#
# [30/138] Processing AbstractsISEE22nd-2011.pdf...
#   ✗ Error processing AbstractsISEE22nd-2011.pdf: [E088] Text of length 2055388 exceeds maximum of 2000000. The parser and NER models require roughly 1GB of temporary memory per 100,000 characters in the input. This means long texts may cause memory allocation errors. If you're not using the parser or NER, it's probably safe to increase the `nlp.max_length` limit. The limit is in number of characters, so you can check whether your inputs are too long by checking `len(text)`.
#
# [31/138] Processing AdamPoupart-Effectsummeroutdoor-2015.pdf...
#   ✓ Extracted 50 unique entities
#   Sample: ['wbgt', 'outdoor heat exposure', 'the temperature']
#
# [32/138] Processing ALLEN-HeatMitigationSoutheastern-2023.pdf...
#   ✓ Extracted 61 unique entities
#   Sample: ['american journal of public health', 'driveshed most cooling centers', 'climate resilience']
#
# [33/138] Processing American J Industrial Med - 2019 - Binazzi - Evaluation of the impact of heat stress on the occurrence of occupational.pdf...
#   ✓ Extracted 85 unique entities
#   Sample: ['temperature percentiles', 'the temperature', 'heat exposure']
#
# [34/138] Processing American J Industrial Med - 2024 - Tetzlaff - Practical Considerations for Using Personal Cooling Garments for Heat Stress.pdf...
#   ✓ Extracted 145 unique entities
#   Sample: ['cooling suits', 'exercise‐heat stress', 'core temperature']
#
# [35/138] Processing annurev-publhealth-060222-034715.pdf...
#   ✓ Extracted 158 unique entities
#   Sample: ['farm workers', 'the temperature', 'heat exposure']
#
# [36/138] Processing applsci-13-08561.pdf...
#   ✓ Extracted 66 unique entities
#   Sample: ['air temperature', 'increased physiological heat strain', 'heat exposure further studies']
#
# [37/138] Processing Arbury-HeatIllnessDeath-2014.pdf...
#   ✓ Extracted 46 unique entities
#   Sample: ['the temperature mmwr', 'heat exposure', 'fans']
#
# [38/138] Processing Arundel-IndirectHealthEffects-1986.pdf...
#   ✓ Extracted 19 unique entities
#   Sample: ['relative hum temperature', 'air conditioning', 'the temperature range']
#
# [39/138] Processing Axelson-Influenceheatexposure-1974.pdf...
#   ✓ Extracted 33 unique entities
#   Sample: ['wbgt', 'if the heat stress', 'heat exposure']
#
# [40/138] Processing Baccini-HeatEffectsMortality-2008.pdf...
#   ✓ Extracted 47 unique entities
#   Sample: ['air temperature', 'the minimum apparent temperature', 'temperature and dew point']
#
# [41/138] Processing Beckett-HeatStressAssociated-1986.pdf...
#   ✓ Extracted 36 unique entities
#   Sample: ['his core temperature', 'core temperature', 'wbgt']
#
# [42/138] Processing Benmarhnia-VulnerabilityHeatrelatedMortality-2015.pdf...
#   ✓ Extracted 62 unique entities
#   Sample: ['air temperature', 'heat waves table', 'local temperature']
#
# [43/138] Processing Bodin-Interventionreduceheat-2016.pdf...
#   ✓ Extracted 31 unique entities
#   Sample: ['wbgt', 'heat exposure', 'chronic cyclic heat stress']
#
# [44/138] Processing Brake-DeepBodyCore-2002.pdf...
#   ✓ Extracted 106 unique entities
#   Sample: ['c dry bulb temperature', 'core temperature', 'the stress']
#
# [45/138] Processing Brake-FluidLossesHydration-2003.pdf...
#   ✓ Extracted 62 unique entities
#   Sample: ['air temperature', 'heat illness', 'acclimatised workers hydration changes']
#
# [46/138] Processing Brearley-InfluenceChronicHeat-2016.pdf...
#   ✓ Extracted 54 unique entities
#   Sample: ['heat illness', 'higher core temperature', 'medical response']
#
# [47/138] Processing Broberg-Waterrestshade-2018.pdf...
#   ✓ Extracted 6 unique entities
#   Sample: ['working group intervention', 'farm workers', 'work environment  health']
#
# [48/138] Processing Bush-ImpactsClimateChange-2011.pdf...
#   ✓ Extracted 34 unique entities
#   Sample: ['the ministry of health', 'temperature ozone', 'future temperature predictions']
#
# [49/138] Processing Calkins-casecrossoverstudyheat-2019.pdf...
#   ✓ Extracted 64 unique entities
#   Sample: ['temperature fields', 'wbgt', 'apparent temperature']
#
# [50/138] Processing Case studies on heat stress related perceptions in different industrial sectors in southern India.pdf...
#   ✓ Extracted 82 unique entities
#   Sample: ['no heat strokes', 'small firms heat exposures', 'heat exposure']
#
# [51/138] Processing Choudhary-HeatStressIllness-2014.pdf...
#   ✓ Extracted 48 unique entities
#   Sample: ['average monthly maximum temperature', 'heatstroke', 'very high temperatures']
#
# [52/138] Processing Ciuha-InteractionIndoorOccupational-2019.pdf...
#   ✓ Extracted 98 unique entities
#   Sample: ['jul     heat wave   july', 'the temperature', 'heat exposure']
#
# [53/138] Processing Climate change-mediated heat stress vulnerability and adaptation strategies among outdoor workers.pdf...
#   ✓ Extracted 63 unique entities
#   Sample: ['air temperature', 'the environmental temperature', 'worker safety policies']
#
# [54/138] Processing Dahl-HeatIndex-2019.pdf...
#   ✓ Extracted 35 unique entities
#   Sample: ['warm ing temperatures', 'that same heat index', 'heat index conditions']
#
# [55/138] Processing Dash-Workplaceheatstress-2011.pdf...
#   ✓ Extracted 92 unique entities
#   Sample: ['the temperature', 'heat exposure', 'rising temperature']
#
# [56/138] Processing document.pdf...
#   ✓ Extracted 72 unique entities
#   Sample: ['air temperature', 'physiological stress', 'the heat exposure risk']
#
# [57/138] Processing DukesDobos-Hazardsheatexposure-1981.pdf...
#   ✓ Extracted 95 unique entities
#   Sample: ['heat exposure', 'oc cupational heat stress', 'lowlevel heat stress']
#
# [58/138] Processing Effects_of_Heat_Stress_Exposure_and_Clim.pdf...
#   ✓ Extracted 98 unique entities
#   Sample: ['campbell  heat waves', 'farm workers', 'the temperature']
#
# [59/138] Processing Emmanuel-Urbanheatislands-2007.pdf...
#   ✓ Extracted 56 unique entities
#   Sample: ['air temperature', 'the temperaturehumidity index', 'the cooling']
#
# [60/138] Processing Enander-Thermalstresshuman-1990.pdf...
#   ✓ Extracted 75 unique entities
#   Sample: ['namely body temperature arousal', 'air temperature', 'the effective temperature']
#
# [61/138] Processing English-EnvironmentalHealthIndicators-2009.pdf...
#   ✓ Extracted 59 unique entities
#   Sample: ['heat illness increasing temperatures', 'a present temperature monitors', 'an extreme temperature event']
#
# [62/138] Processing Evaluation of heat stress and heat strain among employees working outdoors in an extremely hot environment.pdf...
#   ✓ Extracted 37 unique entities
#   Sample: ['wbgt', 'workplace fatalities', 'environmental heat stress measurements']
#
# [63/138] Processing Fortune-WorkattributedIllnessArising-2013.pdf...
#   ✓ Extracted 66 unique entities
#   Sample: ['farm workers', 'heat illness', 'less workplace tenure']
#
# [64/138] Processing fpubh-09-713711.pdf...
#   ✓ Extracted 47 unique entities
#   Sample: ['rising global temperatures  research', 'farm workers', 'heat safety practices']
#
# [65/138] Processing fpubh-10-782811.pdf...
#   ✓ Extracted 131 unique entities
#   Sample: ['workplace conditions', 'farm workers', 'addition dry bulb temperature']
#
# [66/138] Processing fpubh-12-1477186.pdf...
#   ✓ Extracted 88 unique entities
#   Sample: ['covid healthcare workers', 'the environmental temperature', 'core temperature']
#
# [67/138] Processing fspor-05-1274141.pdf...
#   ✓ Extracted 98 unique entities
#   Sample: ['core temperature', 'inﬂuence body temperature', 'the temperature']
#
# [68/138] Processing GeoHealth - 2021 - Morrissey - Heat Safety in the Workplace  Modified Delphi Consensus to Establish Strategies and.pdf...
#   ✓ Extracted 235 unique entities
#   Sample: ['heat safety programs', 'wbgt and heat index', 'cooling abbreviations']
#
# [69/138] Processing GL-PUBLICHEALTHAPPROACH-2015.pdf...
#   ✓ Extracted 18 unique entities
#   Sample: ['material and psychological distress', 'healthy workplaces', 'workplaces']
#
# [70/138] Processing Hanna and Brown 1983.pdf...
#   ✓ Extracted 83 unique entities
#   Sample: ['interior temperatures', 'environ mental temperatures', 'core temperature']
#
# [71/138] Processing Hanna-ClimateChangeRising-2011.pdf...
#   ✓ Extracted 90 unique entities
#   Sample: ['body temperature', 'heat exposure', 'the  workcapacity threshold temperature']
#
# [72/138] Processing Health vs. wealth  Employer  employee and policy-maker perspectives on occupational heat stress across multiple European industries (1).pdf...
#   ✓ Extracted 124 unique entities
#   Sample: ['farm workers', 'personalized heatstress risk forecast', 'perso\xad nal precooling strategies']
#
# [73/138] Processing Health vs. wealth  Employer  employee and policy-maker perspectives on occupational heat stress across multiple European industries.pdf...
#   ✓ Extracted 124 unique entities
#   Sample: ['farm workers', 'personalized heatstress risk forecast', 'perso\xad nal precooling strategies']
#
# [74/138] Processing Heat stress and inadequate sanitary facilities at workplaces   an occupational health concern for women .pdf...
#   ✓ Extracted 84 unique entities
#   Sample: ['highheat exposures', 'some workplaces', 'heatrelated health symptoms']
#
# [75/138] Processing HeatLimitWorkers-1974.pdf...
#   ✓ Extracted 9 unique entities
#   Sample: ['first aid', 'national environmental health association', 'osha source journal of environmental health']
#
# [76/138] Processing HeatRelatedDeathsAmong-2008.pdf...
#   ✓ Extracted 30 unique entities
#   Sample: ['the temperature', 'acclimatization', 'us environmental protection agency  epab']
#
# [77/138] Processing Hunt-HeatStrainHydration-2014.pdf...
#   ✓ Extracted 58 unique entities
#   Sample: ['the industrial workforce', 'heat stress table  figure', 'the core temperature']
#
# [78/138] Processing ijerph-15-00247.pdf...
#   ✓ Extracted 127 unique entities
#   Sample: ['the  european heat waves', 'the temperature', 'heat exposure']
#
# [79/138] Processing ijerph-16-00597.pdf...
#   ✓ Extracted 69 unique entities
#   Sample: ['heat stress impact', 'heat cramps   p', 'several heat wave consequences']
#
# [80/138] Processing ijerph-17-06363-v2.pdf...
#   ✓ Extracted 71 unique entities
#   Sample: ['farm workers', 'heat stress risks', 'latino farm workers']
#
# [81/138] Processing ijerph-18-06303-v2.pdf...
#   ✓ Extracted 67 unique entities
#   Sample: ['the core temperature', 'ohstress', 'the ohstress']
#
# [82/138] Processing ijerph-19-07950-v2.pdf...
#   ✓ Extracted 97 unique entities
#   Sample: ['the surrounding area temperatures', 'heat stress response', 'an effective temperature scale']
#
# [83/138] Processing ijerph-21-01255.pdf...
#   ✓ Extracted 77 unique entities
#   Sample: ['the heat stress program', 'florida agricultural workers', 'the temperature']
#
# [84/138] Processing ijerph-21-01681.pdf...
#   ✓ Extracted 175 unique entities
#   Sample: ['workplace conditions', 'enhanced thermal protection', 'exertional heat illness knowledge']
#
# [85/138] Processing journal.pclm.0000202.pdf...
#   ✓ Extracted 154 unique entities
#   Sample: ['a relatively cool microclimate', 'farm workers', 'heat related stress   individuals']
#
# [86/138] Processing Kjellstrom-ImpactClimateConditions-2016.pdf...
#   ✓ Extracted 54 unique entities
#   Sample: ['systems table  heat exposure', 'workplace conditions', 'hour average temperature']
#
# [87/138] Processing Li-RapidWarmingSummer-2020.pdf...
#   ✓ Extracted 83 unique entities
#   Sample: ['heat exposure', 'monthly temperature', 'summer air temperature']
#
# [88/138] Processing Lundgren.pdf...
#   ✓ Extracted 117 unique entities
#   Sample: ['farm workers', 'moderate heat stress', 'core temperature']
#
# [89/138] Processing Ma-EvaluatingEffectivenessMitigation-2018.pdf...
#   ✓ Extracted 91 unique entities
#   Sample: ['the cooling', 'the temperature', 'urban air temperatures']
#
# [90/138] Processing Matthews-Communicatingdeadlyconsequences-2017.pdf...
#   ✓ Extracted 77 unique entities
#   Sample: ['land tgland extreme temperatures', 'human heat stress authors', 'occupational health']
#
# [91/138] Processing McAllister-Heat-2022.pdf...
#   ✓ Extracted 110 unique entities
#   Sample: ['farm workers', 'year heat stress', 'higherend heat stress days']
#
# [92/138] Processing McDonald-HeatStressImproving-2008.pdf...
#   ✓ Extracted 80 unique entities
#   Sample: ['environmen tal temperatures', 'the dry air temperature', 'knöchel jp  environmental heatillness']
#
# [93/138] Processing McKinnon-HeatStressUnderstanding-2005.pdf...
#   ✓ Extracted 86 unique entities
#   Sample: ['core temperature', 'body temperature', 'heat exposure']
#
# [94/138] Processing MDL-109-163.pdf...
#   ✓ Extracted 214 unique entities
#   Sample: ['farm workers', 'the ambient thermal conditions', 'core temperature']
#
# [95/138] Processing MITCHELL-URBANHEATCLIMATE-2014.pdf...
#   ✓ Extracted 33 unique entities
#   Sample: ['the global temperature baseline', 'american journal of public health', 'florida department of health  descriptive']
#
# [96/138] Processing moran-et-al-2023-beating-the-heat-military-training-and-operations-in-the-era-of-global-warming.pdf...
#   ✓ Extracted 93 unique entities
#   Sample: ['core temperature', 'environmental heat stress', 'al  military heat stress']
#
# [97/138] Processing Morris et al 2020.pdf...
#   ✓ Extracted 124 unique entities
#   Sample: ['farm workers', 'personalized heatstress risk forecast', 'perso\xad nal precooling strategies']
#
# [98/138] Processing MUNSLOW-GlobalisationClimateChange-2010.pdf...
#   ✓ Extracted 21 unique entities
#   Sample: ['ju temperatures', 'the stress', 'apparent temperature']
#
# [99/138] Processing Occupational heat strain in outdoor workers  A comprehensive review and meta-analysis.pdf...
#   ✓ Extracted 222 unique entities
#   Sample: ['projected ambi\xad ent temperatures', 'farm workers', 'water temperature']
#
# [100/138] Processing Ohashi-NumericalSimulationsOutdoor-2014.pdf...
#   ✓ Extracted 50 unique entities
#   Sample: ['air temperature', 'outdoor thermal comfort conditions', 'a heat stress indicator']
#
# [101/138] Processing ONeill-TemperatureExtremesHealth-2009.pdf...
#   ✓ Extracted 108 unique entities
#   Sample: ['temperature  temperature extremes', 'heat exposure', 'the temperature effects']
#
# [102/138] Processing Oppermann-BeyondThresholdApproaches-2018.pdf...
#   ✓ Extracted 81 unique entities
#   Sample: ['heat exposure', 'rising temperature', 'ambient temperatures']
#
# [103/138] Processing Organization-Heatrelatedhealthinformation-2021.pdf...
#   ✓ Extracted 58 unique entities
#   Sample: ['air temperature', 'covid httpswwwwhointinfectionpreventioncampaignscleanhandswhohh', 'the ministry of health']
#
# [104/138] Processing Organization-Longtermurbanplanning-2021.pdf...
#   ✓ Extracted 48 unique entities
#   Sample: ['the cooling', 'dangerous overheating north', 'the temperature']
#
# [105/138] Processing Organization-Reductionsindoorheat-2021.pdf...
#   ✓ Extracted 167 unique entities
#   Sample: ['cooling measures', 'different peak temperatures', 'a largescale heat wave']
#
# [106/138] Processing out.pdf...
#   ✓ Extracted 42 unique entities
#   Sample: ['especially exertional heat stroke', 'a heat acclimated state', 'core temperature']
#
# [107/138] Processing perceived_heat_stress_and_health_effects_on.8.pdf...
#   ✓ Extracted 69 unique entities
#   Sample: ['young construction workers', 'heat illness', 'job stress sexual harassment']
#
# [108/138] Processing Picchio-HighTemperaturesWorkplace-2024.pdf...
#   ✓ Extracted 116 unique entities
#   Sample: ['the temperature distribution  observations', 'the second set temperatures', 'the reference temperature']
#
# [109/138] Processing preprints202410.1280.v1.pdf...
#   ✓ Extracted 64 unique entities
#   Sample: ['heat exposure  numerous studies', 'heat illness', 'florida agricultural workers']
#
# [110/138] Processing Ramsey-Practicalevaluationhot-1987.pdf...
#   ✓ Extracted 58 unique entities
#   Sample: ['air temperature', 'heat illness', 'wbgt']
#
# [111/138] Processing Rasdan_Ismail_2020_J._Phys.%3A_Conf._Ser._1630_012001.pdf...
#   ✓ Extracted 68 unique entities
#   Sample: ['construction worker safety', 'construction worker', 'heatstroke']
#
# [112/138] Processing Reid-EvaluationHeatVulnerability-2012.pdf...
#   ✓ Extracted 41 unique entities
#   Sample: ['thetemperature', 'new mexico health policy commission office', 'heat exposure']
#
# [113/138] Processing Ricketts-CaseOVERHEATEDCONSTRUCTION-2020.pdf...
#   ✓ Extracted 51 unique entities
#   Sample: ['air temperature', 'construction worker', 'work rate relative humidity']
#
# [114/138] Processing s00420-021-01711-0.pdf...
#   ✓ Extracted 103 unique entities
#   Sample: ['the heatstress incidents', 'work microclimate', 'the worker’s physiological conditions']
#
# [115/138] Processing s00484-017-1352-y.pdf...
#   ✓ Extracted 166 unique entities
#   Sample: ['cooling measures', 'the cooling', 'core temperature']
#
# [116/138] Processing s12889-024-19212-3.pdf...
#   ✓ Extracted 163 unique entities
#   Sample: ['thermal stress risk adaptation', 'sweat rate heat', 'pational heat stress resilience']
#
# [117/138] Processing s12940-020-00641-7.pdf...
#   ✓ Extracted 171 unique entities
#   Sample: ['water temperature', 'physiological heat loss responses', 'core temperature']
#
# [118/138] Processing s12992-020-00554-7.pdf...
#   ✓ Extracted 112 unique entities
#   Sample: ['moderate heat stress', 'body temperature', 'heat exposure']
#
# [119/138] Processing s13143-023-00326-4.pdf...
#   ✓ Extracted 80 unique entities
#   Sample: ['tional heat stress', 'heat stress minson', 'the temperature']
#
# [120/138] Processing s40201-015-0199-6.pdf...
#   ✓ Extracted 71 unique entities
#   Sample: ['several days heat waves', 'air temperature', 'heat stress situations']
#
# [121/138] Processing s40279-022-01677-0.pdf...
#   ✓ Extracted 65 unique entities
#   Sample: ['wbgt and heat index', 'various drybulb temperatures', 'heat acclimation variations']
#
# [122/138] Processing s40572-025-00481-y.pdf...
#   ✓ Extracted 106 unique entities
#   Sample: ['workplace conditions', 'workplace characteristics', 'farm workers']
#
# [123/138] Processing Seeba-FeelingHeat-2017.pdf...
#   ✓ Extracted 66 unique entities
#   Sample: ['more heat stress age', 'overall temperature', 'al  and individual health status']
#
# [124/138] Processing strand-HeatStressOccupational-1975.pdf...
#   ✓ Extracted 51 unique entities
#   Sample: ['moderate heat stress', 'ent room temperatures', 'a swedish temperature index']
#
# [125/138] Processing sustainability-14-09234-v2.pdf...
#   ✓ Extracted 53 unique entities
#   Sample: ['heat illness', 'stress injuries', 'air pollution atmospheric temperature']
#
# [126/138] Processing Tuholske-Globalurbanpopulation-2021.pdf...
#   ✓ Extracted 72 unique entities
#   Sample: ['prolonged skin temperatures', 'heatstroke j appl physiol', 'urban extreme heat exposure']
#
# [127/138] Processing Tustin-EvaluationOccupationalExposure-2018.pdf...
#   ✓ Extracted 53 unique entities
#   Sample: ['heat index information', 'unavailable heat index', 'ann work expo health']
#
# [128/138] Processing Tustin-RiskFactorsHeatRelated-2018.pdf...
#   ✓ Extracted 60 unique entities
#   Sample: ['onsite environmental heat', 'heat acclimatization schedules', 'heat illness']
#
# [129/138] Processing Understanding and perceiving heat stress risk control  Critical insights from agriculture workers.pdf...
#   ✓ Extracted 60 unique entities
#   Sample: ['heatrelated illnesses biomonitoring use', 'farm workers', 'workplace implementation strategies']
#
# [130/138] Processing Vaidyanathan-Assessmentextremeheat-2019.pdf...
#   ✓ Extracted 68 unique entities
#   Sample: ['utah department of health vir ginia health', 'percentile heat index values', 'air temperature']
#
# [131/138] Processing Vaneckova-BiometeorologicalIndicesImprove-2011.pdf...
#   ✓ Extracted 107 unique entities
#   Sample: ['the stress', 'the temperature', 'ozone average temperature']
#
# [132/138] Processing Wang-EstimatingOccupationalHeat-2019.pdf...
#   ✓ Extracted 84 unique entities
#   Sample: ['postincidence heat stress estimation', 'the temperature', 'heat exposure']
#
# [133/138] Processing WOJTCZAKJAROSZOWA-HealthComplaintsSicknesses-1986.pdf...
#   ✓ Extracted 27 unique entities
#   Sample: ['a workplace', 'heat exposure', 'the health department']
#
# [134/138] Processing wxaa082 - UTCI.pdf...
#   ✓ Extracted 103 unique entities
#   Sample: ['core temperature', 'body temperature', 'heat exposure']
#
# [135/138] Processing Xiang-Extremeheatoccupational-2015.pdf...
#   ✓ Extracted 95 unique entities
#   Sample: ['heat exposure', 'osha heatstress fatality investigation', 'a nationwide heat illness']
#
# [136/138] Processing Yang-Climaticconditionshuman-2017.pdf...
#   ✓ Extracted 39 unique entities
#   Sample: ['the so january temperature', 'american journal of public health', 'square july temperature effects']
#
# [137/138] Processing Yang-ImpactTemperaturePhysical-2021.pdf...
#   ✓ Extracted 94 unique entities
#   Sample: ['the stress', 'the temperature', 'extreme high temperatures']
#
# [138/138] Processing Zivin-TemperatureExtremesHealth-2016.pdf...
#   ✓ Extracted 97 unique entities
#   Sample: ['body temperature', 'heat exposure', 'urban air temperatures']
#
# ============================================================
# PROCESSING COMPLETE
# ============================================================
# Successfully processed: 137 files
# Failed to process: 1 files
# Total entities extracted: 11661
# Unique entities across all papers: 6474
#
# ============================================================
# ANALYSIS OF IMPROVED EXTRACTION RESULTS
# ============================================================
#
# Top 20 most frequent entities (improved method):
#   heat stress: 129
#   heat: 119
#   heat exposure: 110
#   humidity: 108
#   temperature: 92
#   heat stroke: 84
#   stress: 81
#   occupational health: 79
#   acclimatization: 79
#   wbgt: 77
#   hydration: 70
#   heat waves: 69
#   air conditioning: 63
#   heat exhaustion: 63
#   shade: 62
#   occupational heat stress: 60
#   the workplace: 60
#   temperatures: 58
#   thermal stress: 57
#   ventilation: 57
#
# Top 10 files by entity count:
#   2021-06.pdf: 275 entities
#   GeoHealth - 2021 - Morrissey - Heat Safety in the Workplace  Modified Delphi Consensus to Establish Strategies and.pdf: 235 entities
#   Occupational heat strain in outdoor workers  A comprehensive review and meta-analysis.pdf: 222 entities
#   MDL-109-163.pdf: 214 entities
#   1-s2.0-S2352710224002535-main.pdf: 175 entities
#   ijerph-21-01681.pdf: 175 entities
#   s12940-020-00641-7.pdf: 171 entities
#   Organization-Reductionsindoorheat-2021.pdf: 167 entities
#   s00484-017-1352-y.pdf: 166 entities
#   s12889-024-19212-3.pdf: 163 entities
# '\n# Save results to variables for further analysis\nprint(f"\nResults saved to variables:")\nprint(f"  - entities_all_papers_improved: List of all extracted entities")\nprint(f"  - entity_counts_improved: Counter object with entity frequencies") \nprint(f"  - file_counts_improved: Dictionary with entity counts per file")\nprint(f"  - stats_improved: Processing statistics")\n\n# Optional: Save to file\nsave_to_file = input("\nSave results to text file? (y/n): ").lower().strip() == \'y\'\nif save_to_file:\n    with open(\'improved_entity_extraction_results.txt\', \'w\', encoding=\'utf-8\') as f:\n        f.write("IMPROVED ENTITY EXTRACTION RESULTS\n")\n        f.write("="*50 + "\n\n")\n        \n        f.write(f"Processing Statistics:\n")\n        f.write(f"- Successfully processed: {stats_improved[\'successful\']} files\n")\n        f.write(f"- Failed to process: {stats_improved[\'failed\']} files\n")\n        f.write(f"- Total entities: {stats_improved[\'total_entities\']}\n")\n        f.write(f"- Unique entities: {len(set(entities_all_papers_improved))}\n\n")\n        \n        f.write("Entity Frequencies:\n")\n        for entity, count in entity_counts_improved.most_common(50):\n            f.write(f"{entity}: {count}\n")\n        \n        f.write(f"\nAll Unique Entities ({len(set(entities_all_papers_improved))}):\n")\n        for entity in sorted(set(entities_all_papers_improved)):\n            f.write(f"- {entity}\n")\n    \n    print("Results saved to \'improved_entity_extraction_results.txt\'")\n\nprint(f"\n{\'=\'*60}")\nprint("Ready for further analysis!")\nprint(f"{\'=\'*60}")\n'

# %% [markdown]
# <h2> Summary of Results (Improved  Extraction) </h2>
#
# (the code cell above took approx 30 minutes to run)
#
# 1. 137/138 papers were able to be processed, 6474 unique entities and 11,661 total entities were able to be recognized.
# 2. Core concepts: heat stress, heat exposure, thermal stress
# 3. Specific conditions: heat stroke, heat exhaustion, heat waves
# 4. Technical terms: WBGT, acclimatization, occupational heat stress
# 5. Interventions: air conditioning, shade, ventilation, hydration
# 6. Context: occupational health, the workplace
# 7. Distribution analysis: the frequency distribution (129 down to 57) shows a good balance - the analysis is not too concentrated on just a few terms. The entity counts per file (275 down to 13 for the top 10) indicate comprehensive exraction across documents.

# %%
# Save results to variables for further analysis
print(f"\nResults saved to variables:")
print(f"  - entities_all_papers_improved: List of all extracted entities")
print(f"  - entity_counts_improved: Counter object with entity frequencies") 
print(f"  - file_counts_improved: Dictionary with entity counts per file")
print(f"  - stats_improved: Processing statistics")

# Optional: Save to file
save_to_file = input("\nSave results to text file? (y/n): ").lower().strip() == 'y'
if save_to_file:
    with open('improved_entity_extraction_results.txt', 'w', encoding='utf-8') as f:
        f.write("IMPROVED ENTITY EXTRACTION RESULTS\n")
        f.write("="*50 + "\n\n")
        
        f.write(f"Processing Statistics:\n")
        f.write(f"- Successfully processed: {stats_improved['successful']} files\n")
        f.write(f"- Failed to process: {stats_improved['failed']} files\n")
        f.write(f"- Total entities: {stats_improved['total_entities']}\n")
        f.write(f"- Unique entities: {len(set(entities_all_papers_improved))}\n\n")
        
        f.write("Entity Frequencies:\n")
        for entity, count in entity_counts_improved.most_common(50):
            f.write(f"{entity}: {count}\n")
        
        f.write(f"\nAll Unique Entities ({len(set(entities_all_papers_improved))}):\n")
        for entity in sorted(set(entities_all_papers_improved)):
            f.write(f"- {entity}\n")
    
    print("Results saved to 'improved_entity_extraction_results.txt'")

print(f"\n{'='*60}")
# Out:
# Results saved to variables:
#   - entities_all_papers_improved: List of all extracted entities
#   - entity_counts_improved: Counter object with entity frequencies
#   - file_counts_improved: Dictionary with entity counts per file
#   - stats_improved: Processing statistics
# Save results to text file? (y/n):  y
# Results saved to 'improved_entity_extraction_results.txt'
#
# ============================================================

# %% [markdown]
# <h2> Finding heat stress mitigation measures </h2>

# %%
# Define categories for heat stress problems and solutions
HEAT_CONDITIONS = {
    'heat stress', 'heat strain', 'heat exhaustion', 'heat stroke', 'heat illness',
    'hyperthermia', 'dehydration', 'heat cramps', 'heat rash', 'thermal stress',
    'heat exposure', 'occupational heat stress', 'heat-related illness'
}

MITIGATION_MEASURES = {
    'air conditioning', 'ventilation', 'shade', 'hydration', 'cooling',
    'acclimatization', 'work-rest cycles', 'cooling vest', 'ice vest',
    'misting system', 'evaporative cooling', 'mechanical ventilation',
    'hydration protocol', 'rest breaks', 'training', 'education',
    'personal protective equipment', 'ppe', 'engineering controls',
    'administrative controls', 'medical surveillance'
}

def categorize_entities(entities_list):
    """Categorize entities into problems, solutions, and other"""
    categories = {
        'conditions': [],
        'mitigations': [],
        'other': []
    }
    
    for entity in set(entities_list):
        entity_lower = entity.lower()
        
        if any(condition in entity_lower for condition in HEAT_CONDITIONS):
            categories['conditions'].append(entity)
        elif any(mitigation in entity_lower for mitigation in MITIGATION_MEASURES):
            categories['mitigations'].append(entity)
        else:
            categories['other'].append(entity)
    
    return categories

def calculate_cooccurrence_matrix(texts, entities_list, window_size=50):
    """Calculate co-occurrence matrix for entities within a sliding window"""
    unique_entities = list(set(entities_list))
    entity_to_idx = {entity: i for i, entity in enumerate(unique_entities)}
    n_entities = len(unique_entities)
    
    # Initialize co-occurrence matrix
    cooccurrence_matrix = np.zeros((n_entities, n_entities))
    
    print(f"Calculating co-occurrence for {n_entities} entities...")
    
    for text_idx, text in enumerate(texts):
        if text_idx % 20 == 0:
            print(f"Processing text {text_idx + 1}/{len(texts)}")
            
        text_lower = text.lower()
        
        # Find positions of all entities in this text
        entity_positions = []
        for entity in unique_entities:
            start = 0
            while True:
                pos = text_lower.find(entity.lower(), start)
                if pos == -1:
                    break
                entity_positions.append((pos, entity))
                start = pos + 1
        
        # Sort by position
        entity_positions.sort()
        
        # Calculate co-occurrences within window
        for i, (pos1, entity1) in enumerate(entity_positions):
            for j, (pos2, entity2) in enumerate(entity_positions[i+1:], i+1):
                if abs(pos2 - pos1) <= window_size:
                    idx1, idx2 = entity_to_idx[entity1], entity_to_idx[entity2]
                    cooccurrence_matrix[idx1][idx2] += 1
                    cooccurrence_matrix[idx2][idx1] += 1  # Symmetric
                else:
                    break  # No need to check further
    
    return cooccurrence_matrix, unique_entities

def find_condition_mitigation_pairs(cooccurrence_matrix, entities_list, min_cooccurrence=3):
    """Find condition-mitigation pairs based on co-occurrence"""
    categories = categorize_entities(entities_list)
    entity_to_idx = {entity: i for i, entity in enumerate(entities_list)}
    
    condition_mitigation_pairs = []
    
    for condition in categories['conditions']:
        if condition not in entity_to_idx:
            continue
            
        condition_idx = entity_to_idx[condition]
        
        for mitigation in categories['mitigations']:
            if mitigation not in entity_to_idx:
                continue
                
            mitigation_idx = entity_to_idx[mitigation]
            cooccurrence_count = cooccurrence_matrix[condition_idx][mitigation_idx]
            
            if cooccurrence_count >= min_cooccurrence:
                condition_mitigation_pairs.append({
                    'condition': condition,
                    'mitigation': mitigation,
                    'cooccurrence': int(cooccurrence_count),
                    'condition_freq': entities_list.count(condition),
                    'mitigation_freq': entities_list.count(mitigation)
                })
    
    # Sort by co-occurrence strength
    condition_mitigation_pairs.sort(key=lambda x: x['cooccurrence'], reverse=True)
    return condition_mitigation_pairs

def calculate_frequency_weights(entities_list):
    """Calculate frequency-based weights for entities"""
    entity_counts = Counter(entities_list)
    total_entities = len(entities_list)
    
    frequency_weights = {}
    for entity, count in entity_counts.items():
        frequency_weights[entity] = {
            'count': count,
            'frequency': count / total_entities,
            'weight': np.log(count + 1)  # Log-scaled weight
        }
    
    return frequency_weights

def create_mitigation_recommendations(condition_mitigation_pairs, frequency_weights, top_n=10):
    """Create prioritized mitigation recommendations"""
    recommendations = defaultdict(list)
    
    for pair in condition_mitigation_pairs:
        condition = pair['condition']
        mitigation = pair['mitigation']
        
        # Calculate composite score
        cooccurrence_score = pair['cooccurrence']
        frequency_score = frequency_weights[mitigation]['weight']
        composite_score = cooccurrence_score * frequency_score
        
        recommendations[condition].append({
            'mitigation': mitigation,
            'cooccurrence': pair['cooccurrence'],
            'mitigation_frequency': pair['mitigation_freq'],
            'composite_score': composite_score
        })
    
    # Sort recommendations for each condition
    for condition in recommendations:
        recommendations[condition].sort(key=lambda x: x['composite_score'], reverse=True)
        recommendations[condition] = recommendations[condition][:top_n]
    
    return dict(recommendations)

def visualize_cooccurrence_network(condition_mitigation_pairs, min_cooccurrence=5):
    """Create network visualization of condition-mitigation relationships"""
    G = nx.Graph()
    
    # Add nodes and edges
    for pair in condition_mitigation_pairs:
        if pair['cooccurrence'] >= min_cooccurrence:
            G.add_node(pair['condition'], node_type='condition')
            G.add_node(pair['mitigation'], node_type='mitigation')
            G.add_edge(pair['condition'], pair['mitigation'], weight=pair['cooccurrence'])
    
    # Create visualization
    plt.figure(figsize=(15, 10))
    pos = nx.spring_layout(G, k=3, iterations=50)
    
    # Separate nodes by type
    condition_nodes = [n for n, d in G.nodes(data=True) if d.get('node_type') == 'condition']
    mitigation_nodes = [n for n, d in G.nodes(data=True) if d.get('node_type') == 'mitigation']
    
    # Draw nodes
    nx.draw_networkx_nodes(G, pos, nodelist=condition_nodes, node_color='red', 
                          node_size=1000, alpha=0.7, label='Heat Conditions')
    nx.draw_networkx_nodes(G, pos, nodelist=mitigation_nodes, node_color='blue', 
                          node_size=1000, alpha=0.7, label='Mitigation Measures')
    
    # Draw edges with varying thickness based on co-occurrence
    edges = G.edges(data=True)
    edge_weights = [d['weight'] for u, v, d in edges]
    nx.draw_networkx_edges(G, pos, width=[w/3 for w in edge_weights], alpha=0.6)
    
    # Add labels
    nx.draw_networkx_labels(G, pos, font_size=8, font_weight='bold')
    
    plt.title('Heat Stress Conditions and Mitigation Measures Co-occurrence Network')
    plt.legend()
    plt.axis('off')
    plt.tight_layout()
    plt.show()
    
    return G

# Main analysis function
def analyze_heat_stress_mitigations(entities_list, texts=None):
    """Main function to analyze heat stress mitigations"""
    print("Starting heat stress mitigation analysis...")
    
    # 1. Categorize entities
    print("\n1. Categorizing entities...")
    categories = categorize_entities(entities_list)
    print(f"Found {len(categories['conditions'])} heat conditions")
    print(f"Found {len(categories['mitigations'])} mitigation measures")
    print(f"Found {len(categories['other'])} other entities")
    
    # 2. Calculate frequency weights
    print("\n2. Calculating frequency weights...")
    frequency_weights = calculate_frequency_weights(entities_list)
    
    # 3. Calculate co-occurrence (if texts available)
    if texts is not None:
        print("\n3. Calculating co-occurrence matrix...")
        cooccurrence_matrix, unique_entities = calculate_cooccurrence_matrix(texts, entities_list)
        
        # 4. Find condition-mitigation pairs
        print("\n4. Finding condition-mitigation pairs...")
        condition_mitigation_pairs = find_condition_mitigation_pairs(
            cooccurrence_matrix, unique_entities, min_cooccurrence=2
        )
        
        # 5. Create recommendations
        print("\n5. Creating mitigation recommendations...")
        recommendations = create_mitigation_recommendations(
            condition_mitigation_pairs, frequency_weights
        )
        
        return {
            'categories': categories,
            'frequency_weights': frequency_weights,
            'cooccurrence_matrix': cooccurrence_matrix,
            'unique_entities': unique_entities,
            'condition_mitigation_pairs': condition_mitigation_pairs,
            'recommendations': recommendations
        }
    else:
        # Simple frequency-based analysis without co-occurrence
        print("\n3. Creating frequency-based recommendations...")
        
        # Create simple recommendations based on frequency
        simple_recommendations = {}
        for condition in categories['conditions']:
            condition_freq = frequency_weights.get(condition, {}).get('count', 0)
            if condition_freq > 5:  # Only for frequently mentioned conditions
                mitigation_scores = []
                for mitigation in categories['mitigations']:
                    mit_data = frequency_weights.get(mitigation, {})
                    if mit_data.get('count', 0) > 3:
                        mitigation_scores.append({
                            'mitigation': mitigation,
                            'frequency': mit_data['count'],
                            'weight': mit_data['weight']
                        })
                
                mitigation_scores.sort(key=lambda x: x['weight'], reverse=True)
                simple_recommendations[condition] = mitigation_scores[:10]
        
        return {
            'categories': categories,
            'frequency_weights': frequency_weights,
            'simple_recommendations': simple_recommendations
        }

# Display results function
def display_mitigation_analysis(analysis_results):
    """Display the analysis results in a readable format"""
    
    print("="*80)
    print("HEAT STRESS MITIGATION ANALYSIS RESULTS")
    print("="*80)
    
    categories = analysis_results['categories']
    frequency_weights = analysis_results['frequency_weights']
    
    # Show categorization
    print(f"\nENTITY CATEGORIZATION:")
    print(f"Heat Conditions ({len(categories['conditions'])}):")
    for condition in sorted(categories['conditions'], 
                           key=lambda x: frequency_weights.get(x, {}).get('count', 0), 
                           reverse=True)[:10]:
        count = frequency_weights.get(condition, {}).get('count', 0)
        print(f"  - {condition}: {count} mentions")
    
    print(f"\nMitigation Measures ({len(categories['mitigations'])}):")
    for mitigation in sorted(categories['mitigations'], 
                           key=lambda x: frequency_weights.get(x, {}).get('count', 0), 
                           reverse=True)[:10]:
        count = frequency_weights.get(mitigation, {}).get('count', 0)
        print(f"  - {mitigation}: {count} mentions")
    
    # Show recommendations
    if 'recommendations' in analysis_results:
        recommendations = analysis_results['recommendations']
        print(f"\nCONDITION-MITIGATION RECOMMENDATIONS:")
        print(f"(Based on co-occurrence analysis)")
        
        for condition, mitigations in list(recommendations.items())[:5]:  # Top 5 conditions
            print(f"\nFor '{condition}':")
            for i, rec in enumerate(mitigations[:5], 1):  # Top 5 recommendations
                print(f"  {i}. {rec['mitigation']}")
                print(f"     Co-occurrence: {rec['cooccurrence']}, "
                      f"Frequency: {rec['mitigation_frequency']}, "
                      f"Score: {rec['composite_score']:.2f}")
    
    elif 'simple_recommendations' in analysis_results:
        recommendations = analysis_results['simple_recommendations']
        print(f"\nFREQUENCY-BASED RECOMMENDATIONS:")
        
        for condition, mitigations in list(recommendations.items())[:5]:
            print(f"\nFor '{condition}':")
            for i, rec in enumerate(mitigations[:5], 1):
                print(f"  {i}. {rec['mitigation']} (frequency: {rec['frequency']})")

# Run the analysis (you'll need to provide texts if you want co-occurrence analysis)
print("Running heat stress mitigation analysis...")

# If you have the original texts from PDFs, use this:
# analysis_results = analyze_heat_stress_mitigations(entities_all_papers_improved, texts=all_texts)

# If you only have entities, use this simpler version:
analysis_results = analyze_heat_stress_mitigations(entities_all_papers_improved)

# Display results
display_mitigation_analysis(analysis_results)
# Out:
# Running heat stress mitigation analysis...
# Starting heat stress mitigation analysis...
#
# 1. Categorizing entities...
# Found 1356 heat conditions
# Found 753 mitigation measures
# Found 4365 other entities
#
# 2. Calculating frequency weights...
#
# 3. Creating frequency-based recommendations...
# ================================================================================
# HEAT STRESS MITIGATION ANALYSIS RESULTS
# ================================================================================
#
# ENTITY CATEGORIZATION:
# Heat Conditions (1356):
#   - heat stress: 129 mentions
#   - heat exposure: 110 mentions
#   - heat stroke: 84 mentions
#   - heat exhaustion: 63 mentions
#   - occupational heat stress: 60 mentions
#   - thermal stress: 57 mentions
#   - heat illness: 56 mentions
#   - the heat stress: 39 mentions
#   - occupational heat exposure: 36 mentions
#   - workplace heat exposure: 27 mentions
#
# Mitigation Measures (753):
#   - acclimatization: 79 mentions
#   - hydration: 70 mentions
#   - air conditioning: 63 mentions
#   - shade: 62 mentions
#   - ventilation: 57 mentions
#   - personal protective equipment: 44 mentions
#   - rest breaks: 28 mentions
#   - heat acclimatization: 25 mentions
#   - cooling: 20 mentions
#   - cooling interventions: 13 mentions
#
# FREQUENCY-BASED RECOMMENDATIONS:
#
# For 'moderate heat stress':
#   1. acclimatization (frequency: 79)
#   2. hydration (frequency: 70)
#   3. air conditioning (frequency: 63)
#   4. shade (frequency: 62)
#   5. ventilation (frequency: 57)
#
# For 'heat exhaustion':
#   1. acclimatization (frequency: 79)
#   2. hydration (frequency: 70)
#   3. air conditioning (frequency: 63)
#   4. shade (frequency: 62)
#   5. ventilation (frequency: 57)
#
# For 'uncompensable heat stress':
#   1. acclimatization (frequency: 79)
#   2. hydration (frequency: 70)
#   3. air conditioning (frequency: 63)
#   4. shade (frequency: 62)
#   5. ventilation (frequency: 57)
#
# For 'heat stress exposure':
#   1. acclimatization (frequency: 79)
#   2. hydration (frequency: 70)
#   3. air conditioning (frequency: 63)
#   4. shade (frequency: 62)
#   5. ventilation (frequency: 57)
#
# For 'environmental heat stress':
#   1. acclimatization (frequency: 79)
#   2. hydration (frequency: 70)
#   3. air conditioning (frequency: 63)
#   4. shade (frequency: 62)
#   5. ventilation (frequency: 57)
